# %% [markdown]
# # OCR Text Recognition (Task#1 @ Computer Vision and Internet of Things)
# # -by Abhiram Sharma
# ## <b>Objective</b>
# 1.) Character detector which extracts printed or handwritten text from an image or video.

# %%
#importing Libraries
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
#importing ocr module
reader = easyocr.Reader(['en'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
Image('C:/Users/sharm/Downloads/Review Inputs/OCR/results2.5d8d3b8108cd.png')

# %%
output = reader.readtext('C:/Users/sharm/Downloads/Review Inputs/OCR/results2.5d8d3b8108cd.png',)

# %%
print(output)
# Out:
# [([[174, 15], [253, 15], [253, 47], [174, 47]], 'Image', 0.9907485524101914), ([[34, 48], [429, 48], [429, 116], [34, 116]], '1234567890', 0.9999987936863828), ([[172, 128], [260, 128], [260, 154], [172, 154]], 'Results', 0.9285865832412141), ([[175, 185], [257, 185], [257, 201], [175, 201]], '1234567890', 0.966553208607911)]
